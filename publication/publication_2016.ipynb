# %% [markdown]
# # 2016 GVA Publication

# %% [markdown]
# #### Import packages and define paths to directories

# %%
# this will automatically reload the gva package when changes have been made
#%load_ext autoreload
#%autoreload 2

import pandas as pd
import numpy as np
import os
import sys

# find path to root directory
if os.path.exists(os.path.abspath(os.path.join('outputs'))):
    module_path = os.path.abspath(os.path.join(''))
else: 
    module_path = os.path.abspath(os.path.join('..'))

# add root directory to sys.path so that package can be found
if module_path not in sys.path:
    sys.path.append(module_path)
        
# import package functions
from publication.functions import read_abs, read_charities, read_tourism, read_gva, read_sic91, combine_gva, aggregate_data, make_table

# specify output directory
output_dir = os.path.join(module_path, 'outputs')

#package_dir = os.path.dirname(os.path.abspath(__file__))
#output_dir = os.path.join(module_path, 'outputs')

# set path to raw data excel file
path = '/Volumes/Data/EAU/Statistics/Economic Estimates/2017 publications/November publication/GVA - current/Working_file_dcms_V11 2016 Data.xlsx'

# %% [markdown]
# ## Part 1 - Read in, clean, and aggregate data

# %% [markdown]
# #### Read in and clean up raw data in excel file

# %%
abs = read_abs(path)
charities = read_charities(path)
tourism = read_tourism(path)
gva = read_gva(path)
sic91 = read_sic91(path)

# %% [markdown]
# #### Combine sic level data read in above into a single dataset

# %%
combined_gva = combine_gva(abs, gva, sic91)

# %% [markdown]
# #### Aggregate data to sector level

# %%
agg = aggregate_data(combined_gva, gva, tourism, charities)
agg
# Out:
#      year                                sector  sub-sector           gva
# 0    2010                   Creative Industries     Crafts   2.919926e+02
# 1    2011                   Creative Industries     Crafts   3.076828e+02
# 2    2012                   Creative Industries     Crafts   2.843576e+02
# 3    2013                   Creative Industries     Crafts   2.158877e+02
# 4    2014                   Creative Industries     Crafts   3.955191e+02
# 5    2015                   Creative Industries     Crafts   3.677077e+02
# 6    2016                   Creative Industries     Crafts   4.213056e+02
# 7    2010                   Creative Industries  Publishing  2.448452e+03
# 8    2011                   Creative Industries  Publishing  2.066002e+03
# 9    2012                   Creative Industries  Publishing  2.472863e+03
# 10   2013                   Creative Industries  Publishing  2.255818e+03
# 11   2014                   Creative Industries  Publishing  2.669933e+03
# 12   2015                   Creative Industries  Publishing  3.109508e+03
# 13   2016                   Creative Industries  Publishing  3.347384e+03
# 14   2010                   Creative Industries  Publishing  3.180030e+01
# 15   2011                   Creative Industries  Publishing  2.085413e+01
# 16   2012                   Creative Industries  Publishing  4.815170e+01
# 17   2013                   Creative Industries  Publishing  7.923607e+01
# 18   2014                   Creative Industries  Publishing  5.950989e+01
# 19   2015                   Creative Industries  Publishing  5.051290e+01
# 20   2016                   Creative Industries  Publishing  5.437711e+01
# 21   2010                   Creative Industries  Publishing  2.517547e+03
# 22   2011                   Creative Industries  Publishing  2.346085e+03
# 23   2012                   Creative Industries  Publishing  2.435573e+03
# 24   2013                   Creative Industries  Publishing  2.457487e+03
# 25   2014                   Creative Industries  Publishing  2.425869e+03
# 26   2015                   Creative Industries  Publishing  2.590518e+03
# 27   2016                   Creative Industries  Publishing  2.788691e+03
# 28   2010                   Creative Industries  Publishing  4.431377e+03
# 29   2011                   Creative Industries  Publishing  4.322185e+03
# ..    ...                                   ...         ...           ...
# 747  2014                                    UK         All  1.638722e+06
# 748  2014                      All DCMS sectors         All  2.274977e+05
# 749  2014  Civil Society (Non-market charities)         All  1.978424e+04
# 750  2014                   Creative Industries         All  7.995282e+04
# 751  2014                       Cultural Sector         All  2.452089e+04
# 752  2014                        Digital Sector         All  1.083937e+05
# 753  2014                              Gambling         All  1.038900e+04
# 754  2014                                 Sport         All  7.752427e+03
# 755  2014                              Telecoms         All  3.001200e+04
# 756  2014                               Tourism         All  6.043757e+04
# 757  2015                                    UK         All  1.684937e+06
# 758  2015                      All DCMS sectors         All  2.398360e+05
# 759  2015  Civil Society (Non-market charities)         All  2.128685e+04
# 760  2015                   Creative Industries         All  8.530785e+04
# 761  2015                       Cultural Sector         All  2.563740e+04
# 762  2015                        Digital Sector         All  1.101554e+05
# 763  2015                              Gambling         All  1.105100e+04
# 764  2015                                 Sport         All  8.610180e+03
# 765  2015                              Telecoms         All  3.037200e+04
# 766  2015                               Tourism         All  6.464154e+04
# 767  2016                                    UK         All  1.744435e+06
# 768  2016                      All DCMS sectors         All  2.485153e+05
# 769  2016  Civil Society (Non-market charities)         All  2.093322e+04
# 770  2016                   Creative Industries         All  9.182830e+04
# 771  2016                       Cultural Sector         All  2.676584e+04
# 772  2016                        Digital Sector         All  1.164935e+05
# 773  2016                              Gambling         All  1.064700e+04
# 774  2016                                 Sport         All  9.035494e+03
# 775  2016                              Telecoms         All  2.995500e+04
# 776  2016                               Tourism         All  6.606489e+04
#
# [777 rows x 4 columns]

# %% [markdown]
# #### Save aggregated data to ouputs directory

# %%
agg.to_csv(os.path.join(output_dir, 'gva_aggregate_data_2016.csv'), index=False)

# %% [markdown]
# ## Part 2 - Produce outputs

# %% [markdown]
# #### Read in aggregate data (This is so Part 1 doesn't need to be rerun)

# %%
agg = pd.read_csv(os.path.join(output_dir, 'gva_aggregate_data_2016.csv'))

# %% [markdown]
# #### Create some summary tables

# %%
make_table(agg, 'All')
# Out:
# year                                        2010        2011        2012  \
# sector
# Civil Society (Non-market charities)    19.25028    19.64664    16.10640
# Creative Industries                     63.42460    67.24801    70.72261
# Cultural Sector                         21.06353    21.74142    22.62486
# Digital Sector                          94.50272    99.55116   101.73033
# Gambling                                 8.40100     9.29000     9.88300
# Sport                                    7.02548     7.39687     7.88085
# Telecoms                                24.74500    25.45400    26.01300
# Tourism                                 49.15000    53.94700    57.34300
# All DCMS sectors                       192.67034   205.18862   209.87861
# UK                                    1422.02800  1458.82000  1505.71800
#
# year                                        2013        2014        2015  \
# sector
# Civil Society (Non-market charities)    18.66608    19.78424    21.28685
# Creative Industries                     74.86772    79.95282    85.30785
# Cultural Sector                         23.30614    24.52089    25.63740
# Digital Sector                         106.80038   108.39366   110.15545
# Gambling                                 9.97000    10.38900    11.05100
# Sport                                    7.49058     7.75243     8.61018
# Telecoms                                28.08100    30.01200    30.37200
# Tourism                                 58.99700    60.43757    64.64154
# All DCMS sectors                       220.82625   227.49766   239.83604
# UK                                    1564.43000  1638.72200  1684.93700
#
# year                                        2016
# sector
# Civil Society (Non-market charities)    20.93322
# Creative Industries                     91.82830
# Cultural Sector                         26.76584
# Digital Sector                         116.49352
# Gambling                                10.64700
# Sport                                    9.03549
# Telecoms                                29.95500
# Tourism                                 66.06489
# All DCMS sectors                       248.51526
# UK                                    1744.43500

# %% [markdown]
# #### Save summary tables to a dictionary so they can be easily used by the test script

# %%
summary_tables = {
    'gva_current': make_table(agg, 'All'),
    'gva_current_indexed': make_table(agg, 'All', indexed=True),
    'creative': make_table(agg, 'Creative Industries'),
    'digital': make_table(agg, 'Digital Sector'),
    'culture': make_table(agg, 'Cultural Sector'),
}
